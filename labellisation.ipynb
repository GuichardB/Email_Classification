# %% [markdown]
# # Labellisation des données

# %% [markdown]
# ## Import and prepare Data

# %%
import numpy as np
import pandas as pd
import ast

# %%
data = pd.read_csv("datacleaned/df_10000.CSV")
data = data.drop(['Unnamed: 0'], axis=1) #remove columns creted bc of the to_csv() in the cleaning
data = data.iloc[0:10000]
print(data.shape)
# Out:
# (10000, 3)

# %%
data
# Out:
#                                                   objet  \
# 0     [']', 'mission', 'promotion', 'important', 'me...
# 1     [']', 'message', 'pierre', 'koch', 'personal',...
# 2           ['your', 'instagram', 'password', 'change']
# 3     [']', 'fwd', 'challenge', 'inter', 'entreprise...
# 4            ['confirmation', 'ter', 'ticket', 'order']
# ...                                                 ...
# 9995                               ['tedxwoman', 'way']
# 9996  [']', 'justification', 'medical', 'absence', '...
# 9997  ['early', ']', 'good', 'plan', 'velo', 'schola...
# 9998          ['week', 'review', 'elon', 'big', 'week']
# 9999  [']', 'express', 'reopen', 'tonightgerman', 's...
#
#                                                   corps  \
# 0     ['dear', 'student', 'ambassador', 'lutt', 'you...
# 1     ['english', ']', 'dear', 'fellow', 'student', ...
# 2     ['this', 'confirmation', 'password', 'instagra...
# 3     ['de', 'michel', 'legault', 'sport', 'cc', 'sd...
# ...

# %%
i = 0
while i < len(data):
    data['objet'][i] = ast.literal_eval(data['objet'][i])
    data['corps'][i] = ast.literal_eval(data['corps'][i])
    data['adresse'][i] = ast.literal_eval(data['adresse'][i])
    i+=1

# %%
data['cat'] = ''

# %%
i = 0
data['adressebis'] = ''
while i < len(data):
    if len(data['adresse'][i])==2:
        data['adressebis'][i] = data['adresse'][i][0]+'@'+data['adresse'][i][1]
    else:
        data['adressebis'][i] = data['adresse'][i][0]+'@'+data['adresse'][i][1]+'.'+data['adresse'][i][2]
    i+=1

# %% [markdown]
# ## Creation of functions

# %%
def print_cat(df, str):
    mask = (df['cat'] == str)
    display(df[mask])

# %%
def print_adresses_with_no_cat(df):
    mask = (df['cat'] == '')
    adresses = df[mask]['adressebis'].unique()
    print(len(adresses))
    for i in adresses:
            print(i)

# %%
# Labelling using email adress
def cat_with_list(df, list, str):
    i=0
    while i < len(df):
        if df['adressebis'][i] in list:
            df['cat'][i] = str
        i+=1

    return df

# %%
# Labelling with words in main content
def cat_with_words(df, words, str):
    words_bool = []
    x=0
    while x < len(words):
        words_bool.append(False)
        x+=1
    i=0
    while i < len(df):
        x=0
        while x < len(words):
            words_bool[x] = False
            x+=1
        for word in df['corps'][i]:
            x = 0
            while x < len(words):
                if word == words[x]:
                    words_bool[x] = True
                x+=1
        x=0
        c=0
        while x < len(words):
            if words_bool[x] == True:
                c+=1
            x+=1
        if c == len(words):
            df['cat'][i] = str
        i+=1
    
    return df

# %%
# Labelling with email object
def cat_with_objet(df, str_to_find, str_cat):
    i = 0
    while i < len(df):
        present = False
        for objet in df['objet'][i]:
            if str_to_find in objet:
                present=True
        if present == True:
            df['cat'][i] = str_cat
        i+=1
    return df

# %% [markdown]
# ## 1. Université

# %%
for i in data['adressebis'].unique():
    if 'utt' in i:
        print(i)
# Out:
# etudiants-request@utt.fr
# sport-request@utt.fr
# noreply@utt.fr
# cs03-request@utt.fr
# paul.julien@utt.fr
# sam.noel@utt.fr
# vie.etudiante-request@utt.fr
# francine.durand@utt.fr
# daymail-request@utt.fr
# career-center@utt.fr
# etudiants_troyes-request@utt.fr
# faicel.hnaien@utt.fr
# tous-request@utt.fr
# julien.auffret@utt.fr
# erasmus@utt.fr
# if29-request@utt.fr
# etudiants_ingenieurs-request@utt.fr
# stephane.goudry@utt.fr
# ombeline.pierrard@utt.fr
# ines.di_loreto@utt.fr
# loubna.echajari@utt.fr
# if28-request@utt.fr
# etu_isi-request@utt.fr
# paul.julien@geniusutt.fr
# etudiants_tc-request@utt.fr
# dnum-support@utt.fr
# matthieu.tixier@utt.fr
# lg02-request@utt.fr
# lucie.goffroy@utt.fr
# ran.ding@utt.fr
# rrip-isi@utt.fr
# anna.bodie@utt.fr
# if03-request@utt.fr
# nicolas.thorel@utt.fr
# blaise_kevin.guepie@utt.fr
# nada.matta@utt.fr
# frederique.boulet@utt.fr
# serge.rohmer@utt.fr
# if15-request@utt.fr
# david.beyssac@utt.fr
# ge36-request@utt.fr
# etupay@utt.fr
# ...

# %%
profs = ['faicel.hnaien@utt.fr', 'ines.di_loreto@utt.fr', 'loubna.echajari@utt.fr', 'matthieu.tixier@utt.fr', 'nicolas.thorel@utt.fr',
'blaise_kevin.guepie@utt.fr', 'nada.matta@utt.fr', 'frederique.boulet@utt.fr', 'serge.rohmer@utt.fr', 'martin.mc_carthy@utt.fr',
'joris.falip@utt.fr', 'sophie.loriette@utt.fr', 'thibault.vigier@utt.fr', 'lionel.amodeo@utt.fr', 'guillaume.ducellier@utt.fr', 'benoit.panicaud@utt.fr',
'babiga.birregah@utt.fr', 'mitra.fouladirad@utt.fr', 'sabiha.bruyant@utt.fr', 'benjamin.ruiz@utt.fr', 'jean_marc.nigro@utt.fr', 'matthieu.stange@utt.fr',
'guillaume.doyen@utt.fr', 'caroline.prodhon@utt.fr', 'timothee.toury@utt.fr', 'samiha.ayed@utt.fr', 'leila.merghem_boulahia@utt.fr', 'audrey.morel@utt.fr',
'elias.khoury@utt.fr', 'nadia.gauducheau@utt.fr', 'severine.dautet@utt.fr', 'stephanie.jacotin@utt.fr', 'emmanuel.carquin@utt.fr',
'manuel.canada@utt.fr', 'aurelien.benel@utt.fr', 'magali.colin@avizua.com', 'patrice.faivre@free.fr', 'laura_delatremblaye@hotmail.fr',
'Philippe.Truillet@irit.fr', 'marcos.serrano@irit.fr', 'Richard_doucet_01@hotmail.com', 'Delphine.Faurie@ac-versailles.fr', 'm.zergaoui@groupeonepoint.com',

]

# %%
cours = ['cs03-request@utt.fr', 'if29-request@utt.fr', 'if28-request@utt.fr', 'lg02-request@utt.fr', 'if03-request@utt.fr', 'if15-request@utt.fr',
'ge36-request@utt.fr', 'crunch2021-request@utt.fr', 'ge32-request@utt.fr', 'tn01-request@utt.fr', 'nf21-request@utt.fr', 'andre.smolarz@utt.fr',
'kristine.brousset@utt.fr', 'lg03-request@utt.fr', 'ge34-request@utt.fr', 'ge31-request@utt.fr', 'po03-request@utt.fr',
'math03-request@utt.fr', 'sy01-request@utt.fr', 'nf16-request@utt.fr', 'etudiants_pe-request@utt.fr', 'lo02-request@utt.fr', 'sc04-request@utt.fr',
'ge10-request@utt.fr', 'tresorier@jc-utt.fr']

# %%
event = ['bde@utt.fr', 'integration@utt.fr', 'emilie.colas@utt.fr', 'laura.lejeune@utt.fr', 'eboutique@utt.fr', 'noemie.drege@utt.fr',
'marine@utt.fr', 'skiuttlist-request@utt.fr', 'promo_utt-request@utt.fr', 'noreply@hercule.utt.fr', 'no-reply-rocketchat@utt.fr',
'inte-ce-request@utt.fr', 'integrat@utt.fr', 'stephane.goudry@utt.fr', 'michel.legault@utt.fr', 'skiutt@utt.fr']

# %%
admin = ['etudiants-request@utt.fr', 'sport-request@utt.fr', 'noreply@utt.fr', 'vie.etudiante-request@utt.fr',
'daymail-request@utt.fr', 'etudiants_troyes-request@utt.fr', 'tous-request@utt.fr', 'etudiants_ingenieurs-request@utt.fr', 'etu_isi-request@utt.fr',
'etudiants_tc-request@utt.fr', 'dnum-support@utt.fr', 'rrip-isi@utt.fr', 'etupay@utt.fr', 'cri_int@utt.fr', 'MAILER-DAEMON@z-proxy-02.utt.fr',
'sandra.lebeau@utt.fr', 'ivann.laruelle@utt.fr', 'dse-examens@utt.fr', 'noreply_tickets_scol@utt.fr', 'sandrine.berthier@utt.fr', 'noreply.utt@moveonfr.com',
'etu_isi02-request@utt.fr', 'etu_tc04-request@utt.fr', 'cendrine.charvot@utt.fr', 'francois.iotti@utt.fr', 'charlotte.di_napoli@utt.fr', 'etu_isi05-request@utt.fr',
'thomas.maurer@utt.fr', 'MAILER-DAEMON@z-proxy-01.utt.fr', 'paula.caterino@utt.fr', 'laurence.duteurtre@utt.fr', 'stephanie.rycx@utt.fr', 'emeline.lambert@utt.fr',
'vpe_ce@utt.fr', 'etu_branches-request@utt.fr', 'lea.le_joncour@utt.fr', 'catherine.barbarat@utt.fr', 'alexandre.vial@utt.fr', 'etu_tc03-request@utt.fr',
'etu_tc02-request@utt.fr', 'cri@utt.fr', 'widad.heng@utt.fr', 'nadege.troussier@utt.fr', 'suzie.pons@utt.fr']

# %%
stage = ['francine.durand@utt.fr', 'career-center@utt.fr', 'lucie.goffroy@utt.fr', 'marie_christine.grosmaire@utt.fr',
 'StagesISIRTP22@utt.fr', 'severine.aubry@utt.fr', 'jenny.dutour@utt.fr', 'marion.quillery@utt.fr', 'yassine.ouazene@utt.fr', 
 'StagesISIRTP23@utt.fr', 'st05-request@utt.fr']

# %%
etranger = ['erasmus@utt.fr', 'ombeline.pierrard@utt.fr', 'anna.bodie@utt.fr', 'david.beyssac@utt.fr', 'joanna.kolodziejczyk@utt.fr',
'louison.cousin@utt.fr', 'aurelien.mathieu@utt.fr', 'frederic.bertrand1@utt.fr', 'alexis.nehout@utt.fr', 'andrea.bernard@utt.fr', 'juliette.aulagnon@utt.fr',
'fanny.gioffred@utt.fr', 'christine.ninino@utt.fr', 'alison.vargas@utt.fr', 'melanie.marcinowski@utt.fr', 'morgane.germay@utt.fr',
'elodie.mauffroy@utt.fr']

# %%
univ = profs + cours + event + admin + stage + etranger
data = cat_with_list(data, univ, 'Université')
print_cat(data, 'Université')
# Out:
#                                                   objet  \
# 0     [], mission, promotion, important, message, re...
# 1     [], message, pierre, koch, personal, student, ...
# 3     [], fwd, challenge, inter, entreprise, de, lau...
# 11    [matta, nada, give, feedback, duty, place, pro...
# 13    [re, ], maintenance, online, course, platform,...
# ...                                                 ...
# 9992                                      [], tcm, tcm]
# 9994  [], rappel, reunion, dinformation, double, dip...
# 9996      [], justification, medical, absence, student]
# 9997          [early, ], good, plan, velo, scholarship]
# 9999  [], express, reopen, tonightgerman, spanish, l...
#
#                                                   corps  \
# 0     [dear, student, ambassador, lutt, you, make, p...
# 1     [english, ], dear, fellow, student, for, four,...
# 3     [de, michel, legault, sport, cc, sds, envoy, w...
# 11         [matta, nada, give, feedback, work, deliver]
# ...

# %%
etu = ['paul.julien@utt.fr', 'sam.noel@utt.fr', 'julien.auffret@utt.fr', 'paul.julien@geniusutt.fr', 'anys.nasri@utt.fr', 
'guillaume.gatto@utt.fr', 'lorene.bergougnoux@utt.fr', 'gaelle.lacroix@utt.fr', 'alex.dominguez@utt.fr','ran.ding@utt.fr',
'thomas.meralli_ballou@jc-utt.fr', 'guillaume.marcel@utt.fr', 'matisse.rohel@utt.fr','marwa.ahaouari@jc-utt.fr', 'yann.rakotomalala@utt.fr',
'oscar.benoit@utt.fr', 'mikael.de_fays@utt.fr', 'julien.boulogne@utt.fr', 'solene.fonteneau@utt.fr', 'hugo.brunet@utt.fr', 'axel.perrollaz@utt.fr',
'victor.meyer@utt.fr', 'marie_joyeuse.musoni_uwayo@utt.fr', 'hugo.philipp@jc-utt.fr', 'clement.malidor@utt.fr', 'nathan.maillard@utt.fr', 
'tanguy.goyet@utt.fr', 'baptiste.guichard@utt.fr', 'marion.vailler@utt.fr', 'theo.hoenen@utt.fr', 'louis.lebourgeois@utt.fr',
'imane.dahani@utt.fr', 'evann-bonnaventure@jc-utt.fr', 'maxime.comtois@utt.fr', 'loic.faure@utt.fr', 'antoine.elie@utt.fr', 'paul.duperray@utt.fr',
'jacques.mironneau@utt.fr', 'myriam.griech@utt.fr', 'noemie.hammann@utt.fr', 'valentin.cam@utt.fr', 'tristan.athanase@utt.fr', 'francois.gillot@utt.fr',
'adrien.mialon@utt.fr', 'jeanne.boyer@utt.fr', 'gabriel.sage@utt.fr', 'come.berne@jc-utt.fr', 'daniel.rey_giraud@utt.fr', 'edgar.haond@utt.fr',
'matteo.fidalgo@utt.fr', 'hacene.touzene@utt.fr', 'maxime.thery@geniusutt.fr', 'axel.perrollaz@geniusutt.fr', 'laurelenn.humbert@utt.fr',
'faustin.saillant@utt.fr', 'aya.abdala@utt.fr', 'clemence.morhet@utt.fr', 'chi_nguyen.tran@utt.fr', 'clement.rousseau@utt.fr',
'nicolas.morais@utt.fr', 'marion.vailler@campus3.fr']

# %%
univ_echange = []
for i in data['adressebis'].unique():
    if 'cnu' in i or 'skku' in i or 'sofia' in i or 'cegep' in i:
        univ_echange.append(i)

univ_echange
# Out:
# ['issoffice@skku.edu',
#  'tstancheva@tu-sofia.bg',
#  'fkrastev@tu-sofia.bg',
#  'lib7204@cnu.ac.kr',
#  'd_yosifova@tu-sofia.bg',
#  'ivan.momtchev@tu-sofia.bg',
#  'sofia.warrhen@agorize.com',
#  'jjkim@cnu.ac.kr',
#  'duksoon@cnu.ac.kr',
#  'ftomova@tu-sofia.bg',
#  'int_sor@cnu.ac.kr',
#  'tlawn1234@cnu.ac.kr',
#  'wshim@skku.edu',
#  'incoming@skku.edu',
#  'hugues.paquin@cegeptr.qc.ca',
#  'hongbo@cnu.ac.kr',
#  'imom@tu-sofia.bg',
#  'npetkova@tu-sofia.bg',
#  'dacs.etudiant.etranger@cegeptr.qc.ca',
#  'registraire@cegeptr.qc.ca',
#  'marie.leblanc@cegeptr.qc.ca',
#  'ang@tu-sofia.bg',
#  'sbjo@cnu.ac.kr',
#  'lib7201@cnu.ac.kr',
#  'hyunju.kim@skku.edu',
#  'international@cegeptr.qc.ca',
#  'bernard.park@cnu.ac.kr',
#  'gergana_vacheva@tu-sofia.bg',
#  'hanna@cnu.ac.kr',
#  'inbound@skku.edu',
#  'cegep3rdefisante@cpb19.likuid.com',
#  'dacs@cegeptr.qc.ca',
#  'hcyang@cnu.ac.kr',
#  'hohoiui@skku.edu',
#  'cybercnu@cnu.ac.kr',
#  'dormitory@cnu.ac.kr',
# ...

# %%
data = cat_with_list(data, univ_echange, 'Université')
print_cat(data, 'Université')
# Out:
#                                                   objet  \
# 0     [], mission, promotion, important, message, re...
# 1     [], message, pierre, koch, personal, student, ...
# 3     [], fwd, challenge, inter, entreprise, de, lau...
# 9                [skku, certificate, exchange, student]
# 11    [matta, nada, give, feedback, duty, place, pro...
# ...                                                 ...
# 9992                                      [], tcm, tcm]
# 9994  [], rappel, reunion, dinformation, double, dip...
# 9996      [], justification, medical, absence, student]
# 9997          [early, ], good, plan, velo, scholarship]
# 9999  [], express, reopen, tonightgerman, spanish, l...
#
#                                                   corps  \
# 0     [dear, student, ambassador, lutt, you, make, p...
# 1     [english, ], dear, fellow, student, for, four,...
# 3     [de, michel, legault, sport, cc, sds, envoy, w...
# 9                                                    []
# ...

# %% [markdown]
# ## 2. Publicités

# %%
alerts = []
for i in data['adressebis'].unique():
    if 'alert' in i:
        alerts.append(i)
alerts
# Out:
# ['users-alertes@pap.fr',
#  'jobalerts-noreply@linkedin.com',
#  'alerts@voscours.fr',
#  'alert@chess.com',
#  'alerts@welcometothejungle.com',
#  'recruitment@jobalerts.criteo.com',
#  'offres@email.alerts.keljob.com']

# %%
newsletters = []
for i in data['adressebis'].unique():
    if 'newsletter' in i:
        newsletters.append(i)
newsletters
# Out:
# ['monoprix@newsletter.monoprix.fr',
#  'newsletter@e.transavia.com',
#  'newsletters-noreply@linkedin.com',
#  'newsletter@techcrunch.com',
#  'psg@newsletter.psg.fr',
#  'info@newsletter.letudiant.fr',
#  'newsletter@winamax.fr',
#  'bonsplans@newsletter.oui.sncf',
#  'newsletter@kith.com',
#  'newsletter@news.letudiant.fr',
#  'newsletter@mail2.editions-heritage.com',
#  'newsletter_at_residentadvisor_net_b6yjwgd758_c2573342@privaterelay.appleid.com',
#  'newsletter@emailing.betclic.fr',
#  'newsletter@newsletter-lesechos.lesechos.fr',
#  'newsletter@news.ouibus.com',
#  'newsletter@youfid.fr',
#  'noreply@newsletter.pour-un-reveil-ecologique.fr',
#  'newsletter@news.veepee.fr',
#  'noreply@newsletter.safran-group.com',
#  'no-reply@newsletters.vestiairecollective.com',
#  'news@newsletter.clarks.eu',
#  'superbillets@newsletter.superbillets.com',
#  'newsletters@timeshighereducation.com']

# %%
pub = alerts + newsletters
data = cat_with_list(data, pub, 'Publicité')
print_cat(data, 'Publicité')
# Out:
#                                                   objet  \
# 5                        [alerte, email, studio, paris]
# 8                   [new, job, offer, datum, scientist]
# 12                    [new, job, offer, datum, analyst]
# 16           [the, new, deco, collection, make, travel]
# 46    [vos, destination, preferees, moins, de, eur, ar]
# ...                                                 ...
# 9958                     [alerte, email, studio, paris]
# 9960                           [new, brand, ambassador]
# 9970             [baptiste, say, yes, good, plan, lete]
# 9978          [first, act, complicate, dortmund, paris]
# 9998                    [week, review, elon, big, week]
#
#                                                   corps  \
# 5     [one, ad, correspond, search, rent, apartment,...
# 8     [view, job, offer, france, new, job, offer, fr...
# 12    [datum, analyst, intern, hf, position, availab...
# 16                 [monoprix, operation, rcs, nanterre]
# ...

# %%
data = cat_with_objet(data, 'pub]', 'Publicité')
print_cat(data, 'Publicité')
# Out:
#                                                   objet  \
# 5                        [alerte, email, studio, paris]
# 8                   [new, job, offer, datum, scientist]
# 12                    [new, job, offer, datum, analyst]
# 15                     [pub]join, unity, gdc, showcase]
# 16           [the, new, deco, collection, make, travel]
# ...                                                 ...
# 9970             [baptiste, say, yes, good, plan, lete]
# 9973                              [pub]oscar, new, job]
# 9978          [first, act, complicate, dortmund, paris]
# 9986  [pub]be, eligible, keljob, job, search, servic...
# 9998                    [week, review, elon, big, week]
#
#                                                   corps  \
# 5     [one, ad, correspond, search, rent, apartment,...
# 8     [view, job, offer, france, new, job, offer, fr...
# 12    [datum, analyst, intern, hf, position, availab...
# 15    [mark, calendar, march, keynote, creator, stor...
# ...

# %% [markdown]
# ## 3. Commandes

# %%
orders = ['interflora@votrepanier.com', 'online@booking.lufthansa.com', '']

# %%
#data = cat_with_objet(data, 'commande', '')
data = cat_with_words(data, ['order', 'confirmation'], '')
print_cat(data, 'Commande')
# Out:
# Empty DataFrame
# Columns: [objet, corps, adresse, cat, adressebis]
# Index: []

# %% [markdown]
# ## 4. Economie

# %%
print_adresses_with_no_cat(data)
# Out:
# 1071
# no-reply@mail.instagram.com
# mesbilletsTER-noreply@ter-sncf.fr
# jean-paul@guichard.org
# info_at_glassdoor_com_78mtnx5frd_8c876a48@privaterelay.appleid.com
# patrice.rouille@creteil-habitat.com
# News_Europe@InsideApple.Apple.com
# notifications-noreply@linkedin.com
# paul.julien@utt.fr
# bonjour@superprof.com
# applebooks@insideapple.apple.com
# sam.noel@utt.fr
# no-reply@applicants-digitalrecruiters.com
# contact@pour-un-reveil-ecologique.fr
# noreply@jobbase.io
# contact@alumneye.fr
# interflora@votrepanier.com
# communication@emails.betclic.fr
# service@e.transavia.com
# noreply@t.deliveroo.com
# support@mg.lydia-app.com
# baptiste.guyot94@gmail.com
# verojf@orange.fr
# noreply@client.boursorama.fr
# sie.creteil@dgfip.finances.gouv.fr
# automated@airbnb.com
# julien.auffret@utt.fr
# usine-nouvelle@b2b.infopro-digital.com
# hello_at_fatmap_com_kjq25s98kj_34bd409a@privaterelay.appleid.com
# noreply@clients.boursorama.info
# notification@jobteaser.com
# ...

# %%
banks = ['LCL@messages.lcl.fr', 'lcl@infos.lcl.fr', 'noreply@isic.cartes.lcl.fr', 'noreply@client.boursorama.fr',
'noreply@clients.boursorama.info', 'noreply@boursorama.fr', 'no-reply@boursorama.fr', 'contactez-nous@boursorama-banque-l-offre-de-parrainage.fr',
'noreply-client@boursorama.fr', 'noreply@infos.boursorama.fr', 'confirmation-BRED@bred.fr', 'romuald.bonnin@bred.fr', 'enquete-satisfaction@bred.fr',
'relation_clients@em.bred.fr', 'e-flash@bred.fr', 'cercle.patr.nord.sma@bred.fr', 'abonnement.internet@bred.fr', 'no-reply@revolut.com',
'support@mg.lydia-app.com', 'support@brz1.lydia-app.com', 'support@lydia-app.com', 'supportpro@mg.lydia-app.com']

# %%
cat_with_list(data, banks, 'Economie')
print_cat(data, 'Economie')
# Out:
#                                            objet  \
# 42                                         [eur]
# 48              [be, satisfied, bousorama, bank]
# 65            [practical, guide, customer, area]
# 133                                 [eur, socav]
# 139                     [lcl, wish, great, year]
# ...                                          ...
# 9854     [bank, transfer, eur, deposit, account]
# 9859  [detection, suspicious, banking, activity]
# 9930     [access, my, account, boursorama, bank]
# 9954                                       [eur]
# 9984  [detection, suspicious, banking, activity]
#
#                                                   corps  \
# 42                 [eur, pay, dedffddacdeb, identifier]
# 48    [tell, us, all, hello, baptiste, guichard, 've...
# 65    [discover, customer, area, your, customer, nat...
# 133   [the, sum, charge, account, you, rule, eur, so...
# 139   [you, receive, message, send, we, mail, addres...
# ...

# %% [markdown]
# ## 5. RDVs

# %%
data = cat_with_objet(data, 'rdv', 'RDV')
print_cat(data, 'RDV')
# Out:
#                                                   objet  \
# 805   [], sport, utt, news, renivet, rdv, sur, group...
# 2212  [football, utt, rdv, en, infos, programme, et,...
# 2280                                [re, rdv, novembre]
# 2506                                [re, rdv, novembre]
# 2527      [information, rdv, dermatologie, dr, hamelin]
# 2591  [], sport, utt, rdvs, zoom, sportif, en, decem...
# 3158                  [rdv, confirme, le, lundi, avril]
# 3671    [], utt, supporter, rdv, tomorrow, sport, hall]
# 3881  [], to, sneaker, haspre, effort, revision, spo...
# 4309  [], sport, utt, rdvs, sport, zoom, december, f...
# 5134                      [fcknye, rdv, brussels, lyon]
# 5480           [], td, sc, plan, des, rdv, sur, moodle]
# 6645                        [re, re, re, rdv, novembre]
# 6659                [rdv, confirme, le, mercredi, juin]
# 8392               [rdv, confirme, le, mercredi, fevri]
# 9128                 [fwd, confirmation, rdv, ndeg, du]
# ...

# %% [markdown]
# ## 6. Réseaux sociaux

# %%
print_adresses_with_no_cat(data)
# Out:
# 1048
# no-reply@mail.instagram.com
# mesbilletsTER-noreply@ter-sncf.fr
# jean-paul@guichard.org
# info_at_glassdoor_com_78mtnx5frd_8c876a48@privaterelay.appleid.com
# patrice.rouille@creteil-habitat.com
# News_Europe@InsideApple.Apple.com
# notifications-noreply@linkedin.com
# paul.julien@utt.fr
# bonjour@superprof.com
# applebooks@insideapple.apple.com
# sam.noel@utt.fr
# no-reply@applicants-digitalrecruiters.com
# contact@pour-un-reveil-ecologique.fr
# noreply@jobbase.io
# contact@alumneye.fr
# interflora@votrepanier.com
# communication@emails.betclic.fr
# service@e.transavia.com
# noreply@t.deliveroo.com
# baptiste.guyot94@gmail.com
# verojf@orange.fr
# sie.creteil@dgfip.finances.gouv.fr
# automated@airbnb.com
# julien.auffret@utt.fr
# usine-nouvelle@b2b.infopro-digital.com
# hello_at_fatmap_com_kjq25s98kj_34bd409a@privaterelay.appleid.com
# notification@jobteaser.com
# offres@u2047571.wl.sendgrid.net
# users@pap.fr
# no-reply@carrieres-rolex.com
# ...

# %%
social_media = ['no-reply@mail.instagram.com', 'security@mail.instagram.com', 'groupupdates@facebookmail.com',
'notification@facebookmail.com', 'security@facebookmail.com', 'support@snapchat.zendesk.com', 'no_reply@snapchat.com',
'verify@twitter.com', 'info@twitter.com', 'notifications-noreply@linkedin.com', 'messaging-digest-noreply@linkedin.com',
'invitations@linkedin.com', 'jobs-noreply@linkedin.com', 'messages-noreply@linkedin.com', 'jobs-listings@linkedin.com',
'hit-reply@linkedin.com', 'linkedin@e.linkedin.com', 'member@linkedin.com', 'career-interests-noreply@linkedin.com',
'editors-noreply@linkedin.com', 'inmail-hit-reply@linkedin.com', 'noreply@gotinder.com', 'tinder@mail.tinder.com', 'noreply@gotinder.com',
'noreply@github.com']

# %%
data = cat_with_list(data, social_media, 'Réseaux sociaux')
print_cat(data, 'Réseaux sociaux')
# Out:
#                                                   objet  \
# 2                   [your, instagram, password, change]
# 18    [baptiste, be, your, news, linkedin, news, lin...
# 87                         [julie, smell, new, message]
# 115   [oscar, merci, de, majouter, votre, reseau, li...
# 122   [see, job, offer, like, samada, 's, internship...
# ...                                                 ...
# 9945      [oscar, votre, profil, gagne, en, visibilite]
# 9948  [oscar, merci, de, majouter, votre, reseau, li...
# 9965                        [send, ., thank, answer, .]
# 9974                            [myriam, send, message]
# 9993                                         [be, meet]
#
#                                                   corps  \
# 2     [this, confirmation, password, instagram, acco...
# 18    [learn, baptiste, network, work, discover, net...
# 87    [oscar, benoit, vous, avez, nouveau, message, ...
# 115   [hello, oscar, would, like, join, network, lin...
# ...

# %% [markdown]
# ## 7. Administratif

# %%
print_adresses_with_no_cat(data)
# Out:
# 1024
# mesbilletsTER-noreply@ter-sncf.fr
# jean-paul@guichard.org
# info_at_glassdoor_com_78mtnx5frd_8c876a48@privaterelay.appleid.com
# patrice.rouille@creteil-habitat.com
# News_Europe@InsideApple.Apple.com
# paul.julien@utt.fr
# bonjour@superprof.com
# applebooks@insideapple.apple.com
# sam.noel@utt.fr
# no-reply@applicants-digitalrecruiters.com
# contact@pour-un-reveil-ecologique.fr
# noreply@jobbase.io
# contact@alumneye.fr
# interflora@votrepanier.com
# communication@emails.betclic.fr
# service@e.transavia.com
# noreply@t.deliveroo.com
# baptiste.guyot94@gmail.com
# verojf@orange.fr
# sie.creteil@dgfip.finances.gouv.fr
# automated@airbnb.com
# julien.auffret@utt.fr
# usine-nouvelle@b2b.infopro-digital.com
# hello_at_fatmap_com_kjq25s98kj_34bd409a@privaterelay.appleid.com
# notification@jobteaser.com
# offres@u2047571.wl.sendgrid.net
# users@pap.fr
# no-reply@carrieres-rolex.com
# converse.fr@official.converse.com
# verojf@wanadoo.fr
# hello@service.pumpkin-app.com
# ...

# %%
administrative = ['sie.creteil@dgfip.finances.gouv.fr', 'CVEC-ne-pas-repondre@lescrous.fr', 'KVACFRINFO@iom.int',
'ne-pas-repondre.fil-d-ariane@diplomatie.gouv.fr', 'noreply@interieur.gouv.fr', 'no-reply@visaforkorea.eu', 'veuillez-ne-pas-repondre@urssaf.fr',
'teledep@declaration.urssaf.fr', 'ne-pas-repondre@mes-demarches.iledefrance-mobilites.fr', 'ne_pas_repondre_dialogue@caf.fr', 'noreply@moncompte.ants.gouv.fr',
'ne-pas-repondre@dgfip.finances.gouv.fr', 'ne-pas-repondre@urssaf.fr', 'noreply@urssaf.fr', 'ne-pas-repondre.messervices@grandest.fr',
'severine.le-tutour@diplomatie.gouv.fr', 'ne-pas-repondre@app.assurance-maladie.fr', 'consulat-fr@mofa.go.kr', 'ne-pas-repondre@maprocuration.gouv.fr',
'ne-pas-repondre@timbres.ants.gouv.fr', 'ne-pas-repondre@votre-urssaf.fr', 'ne_pas_repondre@caf.fr', 'no-reply@interieur.gouv.fr', 'no-reply@caf.fr',
'noreply@messervices.etudiant.gouv.fr', 'dcl.iledefrance@urssaf.fr', 'ddsp10-csp-troyes-omp@interieur.gouv.fr', 'amendes10@dgfip.finances.gouv.fr',
'no-reply@sidep.gouv.fr', 'services@immigration.go.tz', 'ne-pas-repondre@declaration.urssaf.fr', 'donotreply@cic.gc.ca']

# %%
data = cat_with_list(data, administrative, 'Administratif')
print_cat(data, 'Administratif')
# Out:
#                                                   objet  \
# 52                      [your, professional, statement]
# 95                       [new, patient, portal, result]
# 101             [studentcvecegouvfr, your, attestation]
# 162           [re, proof, payment, visa, oscar, benoit]
# 293                       [tanzania, visa, application]
# ...                                                 ...
# 9332                [accuse, receive, online, approach]
# 9470           [re, guichard, baptiste, proof, payment]
# 9540  [re, fwd, administrative, seizure, party, holder]
# 9670       [permis, de, conduire, demande, enregistree]
# 9870                [re, fwd, ], repayment, plus, fine]
#
#                                                   corps  \
# 52    [centre, des, finance, publics, service, impot...
# 95    [hello, baptiste, guichard, you, carry, test, ...
# 101   [mrs., mister, we, record, payment, pay, stude...
# 162   [dear, oscar, with, apology, send, email, you,...
# ...

# %% [markdown]
# ## 8. Tickets

# %%
ticket = []
for i in data['adressebis'].unique():
    if 'billet' in i or 'ticket' in i:
        ticket.append(i)
ticket
# Out:
# ['mesbilletsTER-noreply@ter-sncf.fr',
#  'admin@ticket-airfrance.com',
#  'DisneylandParis.fr@print-ticket-athome.com',
#  'noreply_tickets_scol@utt.fr',
#  'billetterie@estac.fr',
#  'billetterie@francegalop.com',
#  'billetterie@chateauversailles-spectacles.fr',
#  'tickets@dice.fm',
#  'billetterie@igloofest.ca',
#  'superbillets@newsletter.superbillets.com',
#  'billetterie@billetterie.estac.fr',
#  'eticket@noreply.thalys.com',
#  'customer_support@email.ticketmaster.com',
#  'tickets-paybox@utc.fr',
#  'eticket@receipt.celio.com']

# %%
ticket.remove('customer_support@email.ticketmaster.com')
ticket.remove('superbillets@newsletter.superbillets.com')
ticket.remove('noreply_tickets_scol@utt.fr')

# %%
data = cat_with_list(data, ticket, 'Ticket')
print_cat(data, 'Ticket')
# Out:
#                                                   objet  \
# 4                    [confirmation, ter, ticket, order]
# 387                  [confirmation, ter, ticket, order]
# 663   [dear, mr, baptiste, guichard, ticket, informa...
# 811   [confirmation, de, votre, reservation, disneyl...
# 1052  [pub][covid, lestac, continue, solidarity, com...
# 1077              [recpitulatory, order, france, galop]
# 1175                 [cancellation, ter, ticket, order]
# 1302    [], lestac, much, football, club, big, famille]
# 1339           [], all, information, champagne, league]
# 1604                               [], happy, birthday]
# 1648       [your, order, chateau, de, versailles, show]
# 2238                      [sncf, ter, failure, payment]
# 2495              [recpitulatory, order, france, galop]
# 2885                  [projection, so, foot, real, psg]
# 3032              [black, friday, entire, online, shop]
# 3575                 [confirmation, ter, ticket, order]
# ...

# %% [markdown]
# ## 9. Jobs

# %%
jobs = []
for i in data['adressebis'].unique():
    if 'career' in i or 'talent' in i or 'job' in i:
        jobs.append(i)
jobs
# Out:
# ['jobalerts-noreply@linkedin.com',
#  'noreply@jobbase.io',
#  'talent@ibm.com',
#  'career-center@utt.fr',
#  'notification@jobteaser.com',
#  'noreply@keljob.com',
#  'jobs-noreply@linkedin.com',
#  'worldwidejobs@allianz.com',
#  'jobs-listings@linkedin.com',
#  'contact@jobijoba.com',
#  'jobs@voscours.fr',
#  'info@jobetudiant.net',
#  'job@neuvoo.com',
#  'do-not-reply@jobs.microsoft.com',
#  'toyota-europe+autoreply@talent.icims.eu',
#  'recruteur11064@emploi-job-atlantic.com',
#  'contact@visiotalent.com',
#  'no-reply@jnj.talent-pool.com',
#  'amazon+email+htbc1-6673ab9a03@talent.icims.com',
#  'stage-administratif-renault@talentpeople.fr',
#  'axa-career-noreply@jobs.axa',
#  'info@jobs.louisvuitton.com',
#  'noreply+jobs@google.com',
#  'noreply@mail.amazon.jobs',
#  'richemont-jobnotification@noreply12.jobs2web.com',
#  'amazon+email+ehb5f-d3604ecb9d@talent.icims.com',
#  'noreply@careers.gs.com',
#  'noreply.careers@loreal-group.com',
# ...

# %%
jobs.remove('career-center@utt.fr')
jobs.remove('career-interests-noreply@linkedin.com')
jobs.remove('notification@jobteaser.com')
jobs.remove('noreply@keljob.com')
jobs.remove('jobs-noreply@linkedin.com')
jobs.remove('offres@email.alerts.keljob.com')
jobs
# Out:
# ['jobalerts-noreply@linkedin.com',
#  'noreply@jobbase.io',
#  'talent@ibm.com',
#  'worldwidejobs@allianz.com',
#  'jobs-listings@linkedin.com',
#  'contact@jobijoba.com',
#  'jobs@voscours.fr',
#  'info@jobetudiant.net',
#  'job@neuvoo.com',
#  'do-not-reply@jobs.microsoft.com',
#  'toyota-europe+autoreply@talent.icims.eu',
#  'recruteur11064@emploi-job-atlantic.com',
#  'contact@visiotalent.com',
#  'no-reply@jnj.talent-pool.com',
#  'amazon+email+htbc1-6673ab9a03@talent.icims.com',
#  'stage-administratif-renault@talentpeople.fr',
#  'axa-career-noreply@jobs.axa',
#  'info@jobs.louisvuitton.com',
#  'noreply+jobs@google.com',
#  'noreply@mail.amazon.jobs',
#  'richemont-jobnotification@noreply12.jobs2web.com',
#  'amazon+email+ehb5f-d3604ecb9d@talent.icims.com',
#  'noreply@careers.gs.com',
#  'noreply.careers@loreal-group.com',
#  'careers@mail02.totalenergies.com',
#  'career@services.dlh.de',
#  'BouyguesTelecomJobs@talentsoft.com',
# ...

# %%
data = cat_with_list(data, jobs, 'Job')
print_cat(data, 'Job')
# Out:
#                                                   objet  \
# 8                   [new, job, offer, datum, scientist]
# 12                    [new, job, offer, datum, analyst]
# 28               [deine, bewerbung, ist, abgeschlossen]
# 39                        [pub]let, keep, busy, august]
# 83                    [new, job, offer, datum, analyst]
# ...                                                 ...
# 9807                  [merci, davoir, postule, damazon]
# 9856                         [keep, track, application]
# 9869    [new, job, offer, datum, scientist, internship]
# 9895  [apple, search, fr, cdi, cdd, specialist, time...
# 9987                    [alerte, emploi, de, richemont]
#
#                                                   corps  \
# 8     [view, job, offer, france, new, job, offer, fr...
# 12    [datum, analyst, intern, hf, position, availab...
# 28    [diese, nachricht, wurde, automatisch, generie...
# 39    [ibm, career, start, hi, oscar, hope, re, well...
# ...

# %%
data = cat_with_words(data, ['internship', 'position'], 'Job')
print_cat(data, 'Job')
# Out:
#                                                   objet  \
# 8                   [new, job, offer, datum, scientist]
# 12                    [new, job, offer, datum, analyst]
# 28               [deine, bewerbung, ist, abgeschlossen]
# 39                        [pub]let, keep, busy, august]
# 83                    [new, job, offer, datum, analyst]
# ...                                                 ...
# 9856                         [keep, track, application]
# 9869    [new, job, offer, datum, scientist, internship]
# 9895  [apple, search, fr, cdi, cdd, specialist, time...
# 9987                    [alerte, emploi, de, richemont]
# 9990                           [thank, apply, adevinta]
#
#                                                   corps  \
# 8     [view, job, offer, france, new, job, offer, fr...
# 12    [datum, analyst, intern, hf, position, availab...
# 28    [diese, nachricht, wurde, automatisch, generie...
# 39    [ibm, career, start, hi, oscar, hope, re, well...
# ...

# %%
contacts = ['no-reply@applicants-digitalrecruiters.com', 'no-reply@carrieres-rolex.com', 'marco.menager@malt.com',
'alexis.pajot@bnpparibas.com', 'h.benallal@criteo.com', 'no-reply@datadoghq.com', 'mdavy@deezer.com', 'recruitment@lvmh.recruitmail.com',
'rafaila.anastasiou@free-now.com', 'noreply@recruiterflowmail.com', 'no-reply@e-recrut.emailing.bnpparibas', 'oceane.boulet@safrangroup.com',
'dinabailey@hellofresh.nl', 'Guillaume.Roussy@stef.com', 'interviews@hirevue.com', 'heloise.aupied@intradef.gouv.fr', 'nimrita@amazon.com',
'kareen.mallet@replikasoftware.com', 'Rh.PDS@porsche.fr', 'humanresources@groupe-societegenerale.com', 'alexandre.levis@fund-channel.com',
'yanelle.agossou.ext@wavestone.com', 'no-reply@message.digitalrecruiters.com', 'thales@myworkday.com', 'nicolas.schnell@louisvuitton.com', 
'Jean-Paul.Isson@sita.aero', 'benoit@accrue.com', 'alice.lokieclegoy@louisvuitton.com', 'dassault_carrieres@profils.org', 'dario@deliveroo.fr',
'jerome.desbois@cebfc.caisse-epargne.fr', 'dgiot@aubay.com', 'fina@myworkday.com', 'safran@profils.org', 'florence.breant@atos.net',
'noreply@global-hr.atos.net', 'Cyril.Rabbe@stef.com', 'julie.massey@backmarket.com', 'no-reply@hire.eu.lever.co', 'vincent.rocchisani@socgen.com',
'corinne.manlhiot@cebfc.caisse-epargne.fr', 'stephane.rebecca@capgemini.com', 'prospection.stage03@intradef.gouv.fr', 'felipe.nechar@backmarket.com',
'lakshl@google.com', 'berengere.peillon@frichti.co', 'Shauna.RIBEIRO@bdl.lu', 'noreply@candidates.workablemail.com', 'elodie.seguy@atos.net',
'mail@hire.lever.co', 'maimouna.gary@pretto.fr', 'lorane.lavergne@pretto.fr', 'hamza@malt.com', 'appleworldwiderecruiting@email.apple.com',
'solene.de-nanteuil@chanel.com', 'chrystele.le-balier@atos.net', 'aline.reau@atos.net', 'alexandra.grunfelder@fund-channel.com',
'opstech-amazonhiring@amazon.com', 'Bernard.Montassier@stef.com', 'theodore.fresnais@ekimetrics.com', 'prospection.stage02@intradef.gouv.fr',
'christophe.meynet@cebfc.caisse-epargne.fr', 'tdelaig@ptc.com', 'hermesemployeur@hermes.recruitmail.com', 'maria-olympia.daroussos@free-now.com',
'David.CHANUSSOT@aprr.fr', 'baptiste.chefdeville@capgemini.com', 'lauriane.acakpo-addra@pretto.fr', 'humanresources@invalidemail.com',
'safiya.mahroug@loreal.com', 'notifications@app.bamboohr.com', 'universityhiring@studentprograms.amazon.com', 'Martin.LAUBEUF@loreal.com',
'romain.roncin@loreal.com', 'rh.webex@bdl.lu', 'David.Boulanger@stef.com', 'no-reply@dataiku.com', 'sujeevan.kandiah@chanel.com',
'tissayme.ktoul@pretto.fr', 'kristina.kulessa@audibene.de', 'sophie.burger@ubisoft.com', 'anastasiia.sobko@dataiku.com', 'laurence.louveau@cebfc.caisse-epargne.fr']

# %%
cat_with_list(data, contacts, 'Job')
print_cat(data, 'Job')
# Out:
#                                                   objet  \
# 8                   [new, job, offer, datum, scientist]
# 12                    [new, job, offer, datum, analyst]
# 26                        [new, opportunity, decathlon]
# 28               [deine, bewerbung, ist, abgeschlossen]
# 39                        [pub]let, keep, busy, august]
# ...                                                 ...
# 9869    [new, job, offer, datum, scientist, internship]
# 9874                                 [re, debut, stage]
# 9895  [apple, search, fr, cdi, cdd, specialist, time...
# 9987                    [alerte, emploi, de, richemont]
# 9990                           [thank, apply, adevinta]
#
#                                                   corps  \
# 8     [view, job, offer, france, new, job, offer, fr...
# 12    [datum, analyst, intern, hf, position, availab...
# 26    [hello, when, apply, decathlon, position, sale...
# 28    [diese, nachricht, wurde, automatisch, generie...
# ...

# %% [markdown]
# ## 10. Persos

# %%
print_adresses_with_no_cat(data)
# Out:
# 848
# jean-paul@guichard.org
# info_at_glassdoor_com_78mtnx5frd_8c876a48@privaterelay.appleid.com
# patrice.rouille@creteil-habitat.com
# News_Europe@InsideApple.Apple.com
# paul.julien@utt.fr
# bonjour@superprof.com
# applebooks@insideapple.apple.com
# sam.noel@utt.fr
# contact@pour-un-reveil-ecologique.fr
# contact@alumneye.fr
# interflora@votrepanier.com
# communication@emails.betclic.fr
# service@e.transavia.com
# noreply@t.deliveroo.com
# baptiste.guyot94@gmail.com
# verojf@orange.fr
# automated@airbnb.com
# julien.auffret@utt.fr
# usine-nouvelle@b2b.infopro-digital.com
# hello_at_fatmap_com_kjq25s98kj_34bd409a@privaterelay.appleid.com
# notification@jobteaser.com
# offres@u2047571.wl.sendgrid.net
# users@pap.fr
# converse.fr@official.converse.com
# verojf@wanadoo.fr
# hello@service.pumpkin-app.com
# Jean.Paul.Guichard@pepsico.com
# appstore@insideapple.apple.com
# support@winamax.fr
# usine-digitale@b2b.infopro-digital.com
# noreply@emeaemail.teams.microsoft.com
# ...

# %%
proches = ['jean-paul@guichard.org', 'verojf@wanadoo.fr', 'Jean.Paul.Guichard@pepsico.com', 'oscarbenoit1@gmail.com', 'audrey.alcaraz00@gmail.com',
'kbeurton@hotmail.fr', 'bergougnouxlorene@yahoo.fr', 'v.guichard.paul@gmail.com', 'antoinetommasi@me.com', 'tbonnef@gmail.com', 'patrice.cointe@orange.com',
'algier.pauline@gmail.com', 'guichardguihot.c@icloud.com', 'jfbenoit@erinette.fr', 'pauljulien0704@gmail.com', 'can.u.beats@gmail.com',
'leundeuange@gmail.com', 'itzneofaze@gmail.com', 'pinkhousestudio09@gmail.com', 'bilal.rhamri@essca.eu', 'lucas.benoit@doctolib.com', 'benoitinvest@orange.fr', 'a.perrollazdu77@gmail.com',
'maxime@comtois.eu', 'morgan.charriere@hotmail.fr', 'thomas.delaiglesia@gmail.com', 'larue-justine@hotmail.fr', 'nathan.maillard22112000@gmail.com', 'alexandrenanquet@gmail.com',
'marceau.canu@gmail.com', 'valentincam4@gmail.com', 'polo.julien49@hotmail.fr', 'jean.paul.guichard@icloud.com', 'oscar.benoit@atos.net',
'3006emma@gmail.com', 'augustinguichard2010@gmail.com',  'bougiegodefroy@gmail.com', 'elise2000.a@gmail.com', 'marie.gabriot@orange.fr', 'awdropthehot@gmail.com',
'yogan.lefouler@gmail.com', 'julie.leroy@geniusglobal.fr', 'marianne.daufresne@gmail.com','jf.benoit.eol@orange.fr','c_guichard@yahoo.com', 
'virginie.guichard@advancerh.fr', 'baptiste.guichard@cebfc.caisse-epargne.fr', 'baptisteguichard@icloud.com','catherine@guichard.org',
'simone@guichard.org', 'verojf@orange.fr', 'paul.duperray@hotmail.com','lbenoitaltis@gmail.com','denis.georgeon@solvay.com', 
'sylvie.sivalingam@gmail.com','zoe.lecarpentier99@gmail.com']

# %%
logement = ['arsenbari2008@hotmail.com', 'mgautier@antillesconciergerie.fr', 'jpmbouwe@yahoo.ca', 'axius6666@hotmail.com',
'villakumquat@gmail.com', 'maygareau@hotmail.com', 'macherevincent@yahoo.fr', 'thibertarnaud@yahoo.fr', 
'agnesboucher7@gmail.com', 'patrice.rouille@creteil-habitat.com']

# %%
jsp = ['albane@agorize.com', 'lena.sanchez@seekube.com','baptiste.guyot94@gmail.com', 'myriam@jedha.co', 'nicoleric@hotmail.com',
'magali.bador-grenie@centralesupelec.fr',  
'alex.bert@live.fr', 'vwalbaum73@gmail.com', 'greg+wir@techcrunch.com',
 'christian.leblainvaux@orange.com','raffalli.antoine2b@gmail.com', 'JeanBaptisteJacob@operaderouen.fr',

 'ait-aoudia@hotmail.com', 'mferreira.ut@gmail.com' 'phy.majou@gmail.com', 'theo.4.roux@gmail.com', 'coffin@em-lyon.com',
 'julienvermuse@gmail.com', 'julie@jedha.co', 'camille@mizogoo.fr', 'k1774201611004@kalilab.fr'
 'laetitia.lc21@gmail.com', 'Frank@c-fs.fr', 'miguellawson1@outlook.com', 'daumainhugo@gmail.com', 'sciphilemas@gmail.com', 'oliva_megann@hotmail.com', 'flagauche@yahoo.fr',
'axius6666@hotmail.com', 'iskandermarine@gmail.com', 
'elodie@serena.vc', 'bdedauphine@gmail.com', 'emilie@serena.vc', 'charlotte@jedha.co', 'hangul4u@globalenskr.com', 'julie.leroy@gventures.co',
'marie-noelle.haritonoff@nokia.com', 'mallika.verma@edhec.edu', 'flagauche@yahoo.fr',
'emilie.favaro@victoriagarden.com', 'j.pihoue@gmail.com', 'cookiegroovie@gmail.com', 'msvb18@gmail.com', 'julie.argheria@skema.edu',
'laetitia.vigneron-field@centralesupelec.fr',
 'dedealca@gmail.com', 'lagibriacoise@gmail.com', 'marvin.mouton@hotmail.fr', 'jean.enzo.gautier@gmail.com', 'maygareau@hotmail.com', 'hugo.daumain@edu.devinci.fr',
'baptiste.payan94@gmail.com','maths.luscan@gmail.com', 'homodavid12@gmail.com', 't.chevalerie@gmail.com']

# %%
perso = proches + etu

# %%
data = cat_with_list(data, perso, 'Perso')
print_cat(data, 'Perso')
# Out:
#                                                   objet  \
# 6     [fwd, fw, repas, anniversaire, mme, simone, gu...
# 19                                                [nan]
# 23                                                [nan]
# 45    [fwd, votre, attestation, rc, locative, habita...
# 58                                   [re, eut+, moodle]
# ...                                                 ...
# 9908                                              [nan]
# 9953           [fwd, rental, confirmation, reservation]
# 9977  [fwd, dear, mr, oscar, benoit, ticket, informa...
# 9980                         [diapo, projet, eut+, grp]
# 9981                                              [nan]
#
#                                                   corps  \
# 6     [original, message, from, christophe, guichard...
# 19    [paul, julien, president, genius, utt, pauljul...
# 23                                                [nan]
# 45    [send, iphone, start, message, transfer, from,...
# ...

# %% [markdown]
# ## 11. Comptes et mdp

# %%
data = cat_with_words(data, ['password', 'change'], 'Account & Password')
print_cat(data, 'Account & Password')
# Out:
#                                            objet  \
# 2            [your, instagram, password, change]
# 143       [*, changez, votre, mot, de, passe, *]
# 208        [account, activity, change, password]
# 317   [detection, suspicious, banking, activity]
# 319                       [alerte, de, securite]
# ...                                          ...
# 9840      [*, changez, votre, mot, de, passe, *]
# 9859  [detection, suspicious, banking, activity]
# 9897                    [*, change, password, *]
# 9923      [*, changez, votre, mot, de, passe, *]
# 9984  [detection, suspicious, banking, activity]
#
#                                                   corps  \
# 2     [this, confirmation, password, instagram, acco...
# 143   [hello, oscar, benoit, your, password, change,...
# 208   [have, change, password, we, notice, airbnb, a...
# 317   [hello, mr, guichard, during, short, period, s...
# 319   [password, create, log, account, if, password,...
# ...

# %%
data = cat_with_words(data, ['account', 'creation'], 'Account & Password')
print_cat(data, 'Account & Password')
# Out:
#                                            objet  \
# 2            [your, instagram, password, change]
# 143       [*, changez, votre, mot, de, passe, *]
# 208        [account, activity, change, password]
# 317   [detection, suspicious, banking, activity]
# 319                       [alerte, de, securite]
# ...                                          ...
# 9840      [*, changez, votre, mot, de, passe, *]
# 9859  [detection, suspicious, banking, activity]
# 9897                    [*, change, password, *]
# 9923      [*, changez, votre, mot, de, passe, *]
# 9984  [detection, suspicious, banking, activity]
#
#                                                   corps  \
# 2     [this, confirmation, password, instagram, acco...
# 143   [hello, oscar, benoit, your, password, change,...
# 208   [have, change, password, we, notice, airbnb, a...
# 317   [hello, mr, guichard, during, short, period, s...
# 319   [password, create, log, account, if, password,...
# ...

# %% [markdown]
# ## 12. Autres

# %% [markdown]
# # Class visualization

# %%
data['cat'].value_counts()
# Out:
# Université            3818
#                       2898
# Publicité              811
# Job                    688
# Réseaux sociaux        615
# Perso                  530
# Economie               314
# Account & Password     185
# Administratif           78
# Ticket                  44
# RDV                     19
# Name: cat, dtype: int64

# %%
mask_empty = data['cat'] == ''
data[mask_empty]
# Out:
#                                                   objet  \
# 7             [debloquez, vite, votre, acce, glassdoor]
# 10    [re, centre, de, formalite, des, entreprise, d...
# 14                [here, new, one, announce, 's, event]
# 21                     [essayez, premium, gratuitement]
# 22    [exceptional, offer, selection, novel, feel, g...
# ...                                                 ...
# 9968                    [your, digital, magazine, week]
# 9972  [jeonjahanggonggweon, yeojeong, annaeseo, guic...
# 9975      [rejoin, la, releve, genius, global, recrute]
# 9985  [centre, tech, vuele, start, station, cyberdef...
# 9995                                   [tedxwoman, way]
#
#                                                   corps  \
# 7     [your, unlimited, access, glassdoor, end, new,...
# 10    [good, evening, oscar, thank, tomorrow, patric...
# 14    [here, new, mac, studio, studio, display, new,...
# 21    [time, higher, time, love, win, with, premium,...
# ...

# %%
print_adresses_with_no_cat(data)
# Out:
# 722
# info_at_glassdoor_com_78mtnx5frd_8c876a48@privaterelay.appleid.com
# patrice.rouille@creteil-habitat.com
# News_Europe@InsideApple.Apple.com
# bonjour@superprof.com
# applebooks@insideapple.apple.com
# contact@pour-un-reveil-ecologique.fr
# contact@alumneye.fr
# interflora@votrepanier.com
# communication@emails.betclic.fr
# service@e.transavia.com
# noreply@t.deliveroo.com
# baptiste.guyot94@gmail.com
# automated@airbnb.com
# usine-nouvelle@b2b.infopro-digital.com
# hello_at_fatmap_com_kjq25s98kj_34bd409a@privaterelay.appleid.com
# notification@jobteaser.com
# offres@u2047571.wl.sendgrid.net
# users@pap.fr
# converse.fr@official.converse.com
# hello@service.pumpkin-app.com
# appstore@insideapple.apple.com
# support@winamax.fr
# usine-digitale@b2b.infopro-digital.com
# noreply@emeaemail.teams.microsoft.com
# noreply@stockx.com
# info@news.leboncoin.fr
# info@enews.histoiredor.com
# bonjour@velib-metropole.fr
# ...
